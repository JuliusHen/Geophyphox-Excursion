# %%
import numpy as np
import plotly.express as px
import pandas as pd
import matplotlib.pyplot as plt

# %%
print("Magnetometer-1")
df = pd.read_csv(r"C:\Users\Julius\sciebo\Arduino\Final\Data\Calibration\1.txt",delim_whitespace=True,names=["x","y","z","T"])
print("mean-T: ",df["T"].mean())
print("delta-T: ",df["T"].max()-df["T"].min())
plt.plot(df["T"])
df = df.iloc[:,:3]
# np.savetxt(r"C:\Users\julik\sciebo\Arduino\Tubes Calibrations\Cal_Data\magneto1_2.txt",df)
# Out:
# Magnetometer-1
# mean-T:  27.04819958847743
# delta-T:  1.75

# %%
print("Magnetometer-2")
df = pd.read_csv(r"C:\Users\julik\sciebo\Arduino\Final\Data\Calibration\2.txt",delim_whitespace=True,names=["x","y","z","T"])
print(df["T"].mean())
plt.plot(df["T"])
df = df.iloc[:,:3]
np.savetxt(r"C:\Users\julik\sciebo\Arduino\Tubes Calibrations\Cal_Data\magneto_2.txt",df)

# %%
print("Magnetometer-3")
df = pd.read_csv(r"C:\Users\Julius\sciebo\Arduino\Final\Data\Calibration\3.txt",delim_whitespace=True,names=["x","y","z","T"])
print("mean-T: ",df["T"].mean())
print("delta-T: ",df["T"].max()-df["T"].min())
plt.plot(df["T"])
df = df.iloc[:,:3]
# np.savetxt(r"C:\Users\julik\sciebo\Arduino\Tubes Calibrations\Cal_Data\magneto1_2.txt",df)
# Out:
# Magnetometer-3
# mean-T:  26.919620098039136
# delta-T:  1.5899999999999999

# %%
print("Magnetometer-4")
df = pd.read_csv(r"C:\Users\julik\sciebo\Arduino\Final\Data\Calibration\4.txt",delim_whitespace=True,names=["x","y","z","T"])
print("mean-T: ",df["T"].mean())
print("delta-T: ",df["T"].max()-df["T"].min())
plt.plot(df["T"])
df = df.iloc[:,:3]
# np.savetxt(r"C:\Users\julik\sciebo\Arduino\Tubes Calibrations\Cal_Data\magneto1_2.txt",df)
# Out:
# Magnetometer-4
# mean-T:  26.181836477987417
# delta-T:  1.4600000000000009

# %%
print("Magnetometer-5")
df = pd.read_csv(r"C:\Users\julik\sciebo\Arduino\Final\Data\Calibration\5.txt",delim_whitespace=True,names=["x","y","z","T"])
print(df["T"].mean())
print("mean-T: ",df["T"].mean())
print("delta-T: ",df["T"].max()-df["T"].min())
df = df.iloc[:,:3]
# np.savetxt(r"C:\Users\julik\sciebo\Arduino\Tubes Calibrations\Cal_Data\magneto1_2.txt",df)
# Out:
# Magnetometer-5
# 23.81611316113161
# mean-T:  23.81611316113161
# delta-T:  1.2600000000000016

# %%
print("Magnetometer-6")
df = pd.read_csv(r"C:\Users\julik\sciebo\Arduino\Final\Data\Calibration\6.txt",delim_whitespace=True,names=["x","y","z","T"])
print("mean-T: ",df["T"].mean())
print("delta-T: ",df["T"].max()-df["T"].min())
plt.plot(df["T"])
df = df.iloc[:,:3]
# np.savetxt(r"C:\Users\julik\sciebo\Arduino\Tubes Calibrations\Cal_Data\magneto1_2.txt",df)
# Out:
# Magnetometer-6
# mean-T:  25.81473922902494
# delta-T:  1.1700000000000017

# %%
print("Magnetometer-7")
df = pd.read_csv(r"C:\Users\julik\sciebo\Arduino\Final\Data\Calibration\7.txt",delim_whitespace=True,names=["x","y","z","T"])
print("mean-T: ",df["T"].mean())
print("delta-T: ",df["T"].max()-df["T"].min())
plt.plot(df["T"])
df = df.iloc[:,:3]
# np.savetxt(r"C:\Users\julik\sciebo\Arduino\Tubes Calibrations\Cal_Data\magneto1_2.txt",df)
# Out:
# Magnetometer-7
# mean-T:  26.459
# delta-T:  1.7300000000000004

# %%
print("Magnetometer-8")
df = pd.read_csv(r"C:\Users\julik\sciebo\Arduino\Final\Data\Calibration\8.txt",delim_whitespace=True,names=["x","y","z","T"])
print("mean-T: ",df["T"].mean())
print("delta-T: ",df["T"].max()-df["T"].min())
plt.plot(df["T"])
df = df.iloc[:,:3]
# np.savetxt(r"C:\Users\julik\sciebo\Arduino\Tubes Calibrations\Cal_Data\magneto1_2.txt",df)
# Out:
# Magnetometer-8
# mean-T:  25.79207039337474
# delta-T:  0.6899999999999977

# %%
# print("Magnetometer-9")
# df = pd.read_csv(r"C:\Users\julik\sciebo\Arduino\Final\Data\Calibration\9.txt",delim_whitespace=True,names=["x","y","z","T"])
# print("mean-T: ",df["T"].mean())
# print("delta-T: ",df["T"].max()-df["T"].min())
# plt.plot(df["T"])
# df = df.iloc[:,:3]
# # np.savetxt(r"C:\Users\julik\sciebo\Arduino\Tubes Calibrations\Cal_Data\magneto9.txt",df)

# %%
print("Magnetometer-10")
df = pd.read_csv(r"C:\Users\Julius\sciebo\Arduino\Final\Data\Calibration\10.txt",delim_whitespace=True,names=["x","y","z","T"])
print("mean-T: ",df["T"].mean())
print("delta-T: ",df["T"].max()-df["T"].min())
plt.plot(df["T"])
df = df.iloc[:,:3]
# np.savetxt(r"C:\Users\julik\sciebo\Arduino\Tubes Calibrations\Cal_Data\magneto_10.txt",df)
# Out:
# Magnetometer-10
# mean-T:  24.886309328968977
# delta-T:  2.169999999999998

# %%
print("Magnetometer-11")
df = pd.read_csv(r"C:\Users\julik\sciebo\Arduino\Final\Data\Calibration\11.txt",delim_whitespace=True,names=["x","y","z","T"])
print("mean-T: ",df["T"].mean())
print("delta-T: ",df["T"].max()-df["T"].min())
plt.plot(df["T"])
df = df.iloc[:,:3]
# np.savetxt(r"C:\Users\julik\sciebo\Arduino\Tubes Calibrations\Cal_Data\magneto11.txt",df)
# Out:
# Magnetometer-11
# mean-T:  26.46950970377937
# delta-T:  0.7800000000000011

# %%
print("Magnetometer-12")
df = pd.read_csv(r"C:\Users\julik\sciebo\Arduino\Final\Data\Calibration\12.txt",delim_whitespace=True,names=["x","y","z","T"])
print("mean-T: ",df["T"].mean())
print("delta-T: ",df["T"].max()-df["T"].min())
plt.plot(df["T"])
df = df.iloc[:,:3]
# np.savetxt(r"C:\Users\julik\sciebo\Arduino\Tubes Calibrations\Cal_Data\magneto12.txt",df)
# Out:
# Magnetometer-12
# mean-T:  25.666644693473962
# delta-T:  0.8900000000000006

# %%
print("Magnetometer-13")
df = pd.read_csv(r"C:\Users\julik\sciebo\Arduino\Final\Data\Calibration\13.txt",delim_whitespace=True,names=["x","y","z","T"])
print("mean-T: ",df["T"].mean())
print("delta-T: ",df["T"].max()-df["T"].min())
plt.plot(df["T"])
df = df.iloc[:,:3]
# np.savetxt(r"C:\Users\julik\sciebo\Arduino\Tubes Calibrations\Cal_Data\magneto13.txt",df)
# Out:
# Magnetometer-13
# mean-T:  24.202135655362053
# delta-T:  1.0199999999999996

# %%
print("Magnetometer-14")
df = pd.read_csv(r"C:\Users\julik\sciebo\Arduino\Final\Data\Calibration\14.txt",delim_whitespace=True,names=["x","y","z","T"])
print("mean-T: ",df["T"].mean())
print("delta-T: ",df["T"].max()-df["T"].min())
plt.plot(df["T"])
df = df.iloc[:,:3]
# np.savetxt(r"C:\Users\julik\sciebo\Arduino\Tubes Calibrations\Cal_Data\magneto14.txt",df)
# Out:
# Magnetometer-14
# mean-T:  26.06482510288066
# delta-T:  0.860000000000003
